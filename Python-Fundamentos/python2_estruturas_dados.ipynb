# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Estruturas de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)</br>
# Aluno [Bruno Miguel Corrêa](https://www.linkedin.com/in/bruno-miguel-corr%C3%AAa-64ab60171/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Listas;</li>
#   <li>Conjuntos;</li>
#   <li>Dicionários.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Listas

# %% [markdown]
# Criei uma lista chamada `filmes` com o nome dos 10 primeiros filmes mais bem avaliados no site no [IMDB](https://www.imdb.com/chart/top/). Imprima o resultado.

# %%
filmes = [
    'Um sonho de liberdade', 'O poderoso chefão', 'Batman: O cavaleiro das trevas',\
    'O poderoso chefao 2', '12 homens e uma sentença', 'A lista de Schindler',\
    'O senhor dos anéis: O retorno do rei', 'Pulp fiction: Tempo de violência',\
    'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito'
]
print(filmes)
# Out:
# ['Um sonho de liberdade', 'O poderoso chefão', 'Batman: O cavaleiro das trevas', 'O poderoso chefao 2', '12 homens e uma sentença', 'A lista de Schindler', 'O senhor dos anéis: O retorno do rei', 'Pulp fiction: Tempo de violência', 'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito']

# %% [markdown]
# Simule a movimentação do *ranking*. Utilize os métodos `insert` e `pop` para trocar a posição do primeiro e do segundo filme da lista. Imprima o resultado.

# %%
filmes.insert(1, filmes[0])
filmes.insert(0, filmes[2])
filmes.pop(2)
filmes.pop(2)
print(filmes)
# Out:
# ['O poderoso chefão', 'Um sonho de liberdade', 'Batman: O cavaleiro das trevas', 'O poderoso chefao 2', '12 homens e uma sentença', 'A lista de Schindler', 'O senhor dos anéis: O retorno do rei', 'Pulp fiction: Tempo de violência', 'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito']

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Conjuntos

# %% [markdown]
# Aconteceu um erro no seu *ranking*. Simule a duplicação dos três últimos filmes da lista. Imprima o resultado.

# %%
filmes.append(filmes[-3])
filmes.append(filmes[-3])
filmes.append(filmes[-3])
print(filmes)
# Out:
# ['Um sonho de liberdade', 'O poderoso chefão', 'Batman: O cavaleiro das trevas', 'O poderoso chefao 2', '12 homens e uma sentença', 'A lista de Schindler', 'O senhor dos anéis: O retorno do rei', 'Pulp fiction: Tempo de violência', 'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito', 'Pulp fiction: Tempo de violência', 'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito']

# %% [markdown]
# Utiliza a conversão `set` e `list` para remover os valores duplicados. Imprima o resultado.

# %%
print(
    list(
        set(filmes)
    )
)
# Out:
# ['12 homens e uma sentença', 'O senhor dos anéis: O retorno do rei', 'Um sonho de liberdade', 'Batman: O cavaleiro das trevas', 'O poderoso chefao 2', 'A lista de Schindler', 'Pulp fiction: Tempo de violência', 'Três homens em conflito', 'O senhor dos anéis: A sociedade do anel', 'O poderoso chefão']

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Dicionários

# %% [markdown]
# Repita os exercícios da parte 1 (listas). Os elementos da lista `filmes` devem ser dicionários no seguinte formato: `{'nome': <nome-do-filme>, 'ano': <ano do filme>}, 'sinopse': <sinopse do filme>}`.

# %%
filmes = {
    'nome': filmes,
    'ano': [1994, 1972, 2008, 1974, 1957, 1993, 2003, 1994, 2001, 1996]
}

# %%
print(filmes)
# Out:
# {'nome': ['Um sonho de liberdade', 'O poderoso chefão', 'Batman: O cavaleiro das trevas', 'O poderoso chefao 2', '12 homens e uma sentença', 'A lista de Schindler', 'O senhor dos anéis: O retorno do rei', 'Pulp fiction: Tempo de violência', 'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito', 'Pulp fiction: Tempo de violência', 'O senhor dos anéis: A sociedade do anel', 'Três homens em conflito'], 'ano': [1994, 1972, 2008, 1974, 1957, 1993, 2003, 1994, 2001, 1996]}
